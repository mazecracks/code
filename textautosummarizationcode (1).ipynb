# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
#User-Agent Header: 
#Some websites block access from web scraping bots. You can try setting a User-Agent 
#header to mimic a regular web browser when making the request

url = 'https://www.signifyd.com/resources/fraud-101/why-liable/'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}
req = urllib.request.Request(url, headers=headers)
page = urllib.request.urlopen(req).read().decode('utf8', 'ignore')

# %%
#exttract all the page content
soup = BeautifulSoup(page,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.signifyd.com/xmlrpc.php" rel="pingback"/>
# <script crossorigin="anonymous" src="https://js.sentry-cdn.com/0120f3d31f4746b89598cdd6f9af5321.min.js"></script>
# <!-- Google Chrome Frame for IE -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <!--[if lt IE 9]>
# 	<script src="https://www.signifyd.com/wp-content/themes/bb-theme/js/html5shiv.js"></script>
# 	<script src="https://www.signifyd.com/wp-content/themes/bb-theme/js/respond.min.js"></script>
# <![endif]-->
# <!-- OneTrust Cookies Consent Notice start -->
# ...

# %%
soups = soup.find_all('div', class_ = 'post-body')

# %%
soups
# Out:
# [<div class="post-body">
#  <p>When a merchant starts accepting online orders, they’ve officially entered the <strong>card not present</strong> world.</p>
#  <p>To a consumer, the decision between purchasing online or in-store is simply a calculation of convenience, price and availability.</p>
#  <p>To a merchant however, a purchase online versus in-store are two very different scenarios, especially when it concerns liability for accepting a fraudulent transaction.</p>
#  <p>Let’s dive into an example that will help illustrate the difference for merchants. This will help you to understand who pays for <a href="https://www.signifyd.com/resources/fraud-101/why-does-online-fraud-occur/">credit card fraud and chargeback</a> merchant rights.</p>
#  <p>John Smith is a video-game enthusiast, eagerly awaiting the release of a new game. Release day has finally come, and he heads down to his local store to purchase it, happy to discover that he can grab a copy in-store.</p>
# ...

# %%
#extract the content in the paragraph
for content_div in soups:
    content_text = content_div.get_text()
    print(content_text)
# Out:
# When a merchant starts accepting online orders, they’ve officially entered the card not present world.
# To a consumer, the decision between purchasing online or in-store is simply a calculation of convenience, price and availability.
# To a merchant however, a purchase online versus in-store are two very different scenarios, especially when it concerns liability for accepting a fraudulent transaction.
# Let’s dive into an example that will help illustrate the difference for merchants. This will help you to understand who pays for credit card fraud and chargeback merchant rights.
# John Smith is a video-game enthusiast, eagerly awaiting the release of a new game. Release day has finally come, and he heads down to his local store to purchase it, happy to discover that he can grab a copy in-store.
# ...

# %%
content_text
# Out:
# '\nWhen a merchant starts accepting online orders, they’ve officially entered the\xa0card not present\xa0world.\nTo a consumer, the decision between purchasing online or in-store is simply a calculation of convenience, price and availability.\nTo a merchant however, a purchase online versus in-store are two very different scenarios, especially when it concerns liability for accepting a fraudulent transaction.\nLet’s dive into an example that will help illustrate the difference for merchants. This will help you to understand who pays for credit card fraud and chargeback merchant rights.\nJohn Smith is a video-game enthusiast, eagerly awaiting the release of a new game. Release day has finally come, and he heads down to his local store to purchase it, happy to discover that he can grab a copy in-store.\nFor the brick-and-mortar merchant, this is a\xa0card present\xa0(CP) transaction, meaning the cardholder, John Smith, is physically present with the card at the point of purchase. When 
# ...

# %%
# replace both newline characters and non-breaking space characters with regular spaces
content_text = content_text.replace('\n', ' ').replace('\xa0', ' ')

# %%
content_text
# Out:
# ' When a merchant starts accepting online orders, they’ve officially entered the card not present world. To a consumer, the decision between purchasing online or in-store is simply a calculation of convenience, price and availability. To a merchant however, a purchase online versus in-store are two very different scenarios, especially when it concerns liability for accepting a fraudulent transaction. Let’s dive into an example that will help illustrate the difference for merchants. This will help you to understand who pays for credit card fraud and chargeback merchant rights. John Smith is a video-game enthusiast, eagerly awaiting the release of a new game. Release day has finally come, and he heads down to his local store to purchase it, happy to discover that he can grab a copy in-store. For the brick-and-mortar merchant, this is a card present (CP) transaction, meaning the cardholder, John Smith, is physically present with the card at the point of purchase. When a consumer makes a
# ...

# %%
text = getTextWaPo(articleurl)

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords # import a set of stopwords
from string import punctuation # import a set of punctuationmarks

# %%
# Now you can use sent_tokenize
sents = sent_tokenize(content_text)

# %%
sents
# Out:
# [' When a merchant starts accepting online orders, they’ve officially entered the card not present world.',
#  'To a consumer, the decision between purchasing online or in-store is simply a calculation of convenience, price and availability.',
#  'To a merchant however, a purchase online versus in-store are two very different scenarios, especially when it concerns liability for accepting a fraudulent transaction.',
#  'Let’s dive into an example that will help illustrate the difference for merchants.',
#  'This will help you to understand who pays for credit card fraud and chargeback merchant rights.',
#  'John Smith is a video-game enthusiast, eagerly awaiting the release of a new game.',
#  'Release day has finally come, and he heads down to his local store to purchase it, happy to discover that he can grab a copy in-store.',
# ...

# %%
words_sent = word_tokenize(content_text.lower())
words_sent
# Out:
# ['when',
#  'a',
#  'merchant',
#  'starts',
#  'accepting',
#  'online',
#  'orders',
#  ',',
#  'they',
#  '’',
#  've',
#  'officially',
#  'entered',
#  'the',
#  'card',
#  'not',
#  'present',
#  'world',
#  '.',
#  'to',
#  'a',
#  'consumer',
#  ',',
#  'the',
#  'decision',
#  'between',
#  'purchasing',
#  'online',
#  'or',
#  'in-store',
#  'is',
#  'simply',
#  'a',
#  'calculation',
#  'of',
#  'convenience',
#  ',',
#  'price',
#  'and',
#  'availability',
#  '.',
#  'to',
#  'a',
#  'merchant',
#  'however',
#  ',',
#  'a',
#  'purchase',
#  'online',
#  'versus',
#  'in-store',
#  'are',
#  'two',
#  'very',
#  'different',
#  'scenarios',
#  ',',
#  'especially',
#  'when',
#  'it',
#  'concerns',
#  'liability',
#  'for',
#  'accepting',
#  'a',
#  'fraudulent',
#  'transaction',
#  '.',
#  'let',
#  '’',
#  's',
#  'dive',
#  'into',
#  'an',
#  'example',
#  'that',
#  'will',
#  'help',
#  'illustrate',
#  'the',
#  'difference',
#  'for',
#  'merchants',
# ...

# %%
#list of stopwords in nltk
_StopWords = set(stopwords.words('english')+list(punctuation))
_StopWords
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
# ...

# %%
#removing stopwords i.e bringing out the main word
wostopwordss = [word for word in words_sent if word not in _StopWords]
print(wostopwordss)
# Out:
# ['merchant', 'starts', 'accepting', 'online', 'orders', '’', 'officially', 'entered', 'card', 'present', 'world', 'consumer', 'decision', 'purchasing', 'online', 'in-store', 'simply', 'calculation', 'convenience', 'price', 'availability', 'merchant', 'however', 'purchase', 'online', 'versus', 'in-store', 'two', 'different', 'scenarios', 'especially', 'concerns', 'liability', 'accepting', 'fraudulent', 'transaction', 'let', '’', 'dive', 'example', 'help', 'illustrate', 'difference', 'merchants', 'help', 'understand', 'pays', 'credit', 'card', 'fraud', 'chargeback', 'merchant', 'rights', 'john', 'smith', 'video-game', 'enthusiast', 'eagerly', 'awaiting', 'release', 'new', 'game', 'release', 'day', 'finally', 'come', 'heads', 'local', 'store', 'purchase', 'happy', 'discover', 'grab', 'copy', 'in-store', 'brick-and-mortar', 'merchant', 'card', 'present', 'cp', 'transaction', 'meaning', 'cardholder', 'john', 'smith', 'physically', 'present', 'card', 'point', 'purchase', 'consumer', 'makes
# ...

# %%
#construct a frequency distribution of words
from nltk.probability import FreqDist
freq = FreqDist(wostopwordss)
freq
# Out:
# FreqDist({'merchant': 28, 'card': 18, '’': 12, 'transaction': 12, 'online': 11, 'fraudulent': 11, 'purchase': 9, 'cardholder': 9, 'bank': 9, 'present': 7, ...})

# %%
#gives us the words with the highest frequencies

from heapq import nlargest
nlargest(10, freq, key=freq.get)
# Out:
# ['merchant',
#  'card',
#  '’',
#  'transaction',
#  'online',
#  'fraudulent',
#  'purchase',
#  'cardholder',
#  'bank',
#  'present']

# %%
from collections import defaultdict
ranking = defaultdict(int)

for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
ranking
# Out:
# defaultdict(int,
#             {0: 89,
#              1: 25,
#              2: 93,
#              3: 23,
#              4: 62,
#              5: 15,
#              6: 28,
#              7: 121,
#              8: 108,
#              9: 37,
#              10: 39,
#              11: 115,
#              12: 116,
#              13: 89,
#              14: 33,
#              15: 92,
#              16: 56,
#              17: 63,
#              18: 106,
#              19: 111,
#              20: 46,
#              21: 41,
#              22: 85,
#              23: 102,
#              24: 150,
#              25: 151,
#              26: 187,
#              27: 19,
#              28: 34,
#              29: 92,
#              30: 144,
#              31: 114})

# %%
sents_idx = nlargest(4, ranking, key=ranking.get)
sents_idx
# Out:
# [26, 25, 24, 30]

# %%
[sents[j] for j in sorted(sents_idx)]
# Out:
# ['Second, the merchant’s bank (known as the acquiring bank, with whom the merchant stores their money) heavily monitors their customers for fraud acceptance and may charge a fee for every merchant chargeback received – amplifying how important the question of who is responsible for chargebacks really is.',
#  'And, should the merchant start to process a large volume of fraudulent transactions, an acquiring bank may not only raise card fees sharply, they may take steps to shut down an online merchant’s account.',
#  'To sum up, when it comes to credit card fraud, merchant responsibility is as follows: Card present transactions occur in-store, where the merchant can review the identifying documents of the cardholder for legitimacy and take other security steps, like using a chip-enabled card terminal, to further confirm the validity of the purchase.',
# ...

# %%
#this create a function fo all the process followed to summarise the text. it can be reused for other articles. 

def summarize(text, n):
    sents = sent_tokenize(text)
    
    assert n <= len(sents)
    word_sent = word_tokenize(text.lower())
    _stopwords = set(stopwords.words('english') + list(punctuation))
    
    word_sent=[word for word in words_sent if word not in _stopwords]
    freq = FreqDist(words_sent)
    
    
    ranking = defaultdict(int)
    
    for i,sent in enumerate(sents):
        for w in word_tokenize(sent.lower()):
            if w in freq:
                ranking[i] += freq[w]
             
        
    sents_idx = nlargest(n, ranking, key=ranking.get)
    return [sents[j] for j in sorted(sents_idx)]

# %%
summarize(content_text,2)
# Out:
# ['First, the total cost to the merchant for accepting one fraudulent transaction is often more than twice the cost of the transaction itself, since they cannot recover the original fraudulent shipment and must also refund the scammed customer.',
#  'To sum up, when it comes to credit card fraud, merchant responsibility is as follows: Card present transactions occur in-store, where the merchant can review the identifying documents of the cardholder for legitimacy and take other security steps, like using a chip-enabled card terminal, to further confirm the validity of the purchase.']
